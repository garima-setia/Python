# %%
class allseq:
    """A class that stores all types of biological sequences"""
    def __init__(self, sequence, seqtype, species):
        self.sequence=sequence
        self.seqtype=seqtype
        self.seqtype=seqtype

# %%
inputseq=allseq("AUGGAGGCAUAA","RNA","a")

# %%
class dna(allseq):
    """A class that stores DNA sequences"""
    def __init__(self, sequence, seqtype, species):
        self.sequence=sequence
        self.seqtype=seqtype
        self.seqtype=seqtype
    def dnafreq(self): 
        if "U" in inputseq.sequence: #tells the frequency of each nucleotide in DNA
            inputseq.sequence=inputseq.sequence.replace("U","T")
            freq_A=inputseq.sequence.count("A")/len(inputseq.sequence)
            freq_C=inputseq.sequence.count("C")/len(inputseq.sequence)
            freq_G=inputseq.sequence.count("G")/len(inputseq.sequence)
            freq_T=inputseq.sequence.count("T")/len(inputseq.sequence)
            print("Frequency of A is: " +str(freq_A)+", C is: "+str(freq_C)+", G is: "+str(freq_G)+", and T is: "+str(freq_T))
    def validseq(self):
        """It validates if the sequence will code for protein or not"""
        if "U" in inputseq.sequence:
            inputseq.sequence=inputseq.sequence.replace("U","T")
            if len(inputseq.sequence)%3 == 0:
                print("Sequence is multiple of 3")
                if "ATG" in inputseq.sequence:
                    print("sequence has start codon")
                    if "TAA" or "TAG" or "TGA" in inputseq.sequence:
                        print("sequence has stop codon")
                    else:
                        print("No stop codon")
                else:
                    print("No start codon") 
        elif "T" in inputseq.sequence:
            if len(inputseq.sequence)%3 == 0:
                print("Sequence is multiple of 3")
                if "ATG" in inputseq.sequence:
                    print("sequence has start codon")
                    if "TAA" or "TAG" or "TGA" in inputseq.sequence:
                        print("sequence has stop codon")
                    else:
                        print("No stop codon")
                else:
                    print("No start codon")

# %%
class rna(allseq):
    """A class that stores RNA sequences"""
    def __init__(self, sequence, seqtype, species):
        self.sequence=sequence
        self.seqtype=seqtype
        self.seqtype=seqtype
    def rnafreq():
        if "U" in inputseq.sequence: #tells the frequency of each nucleotide in RNA
            freq_A=inputseq.sequence.count("A")/len(inputseq.sequence)
            freq_C=inputseq.sequence.count("C")/len(inputseq.sequence)
            freq_G=inputseq.sequence.count("G")/len(inputseq.sequence)
            freq_U=inputseq.sequence.count("U")/len(inputseq.sequence)
            print("Frequency of A is: " +str(freq_A)+", C is: "+str(freq_C)+", G is: "+str(freq_G)+", and U is: "+str(freq_U))
    def validseq(self):
        """It validates if the sequence will code for protein or not"""
        if "U" in inputseq.sequence:
            if len(inputseq.sequence)%3 == 0:
                print("Sequence is multiple of 3")
                if "ATG" in inputseq.sequence:
                    print("sequence has start codon")
                    if "TAA" or "TAG" or "TGA" in inputseq.sequence:
                        print("sequence has stop codon")
                    else:
                        print("No stop codon")
                else:
                    print("No start codon") 
        else:
            print("sequence is not multiple of 3")

# %%
class aminoacid(allseq):
    def __init__(self, sequence, seqtype, species):
        self.sequence=sequence
        self.seqtype=seqtype
        self.seqtype=seqtype
    def translation(self):
        """translates RNA/DNA into protein"""
        if "U" in inputseq.sequence: 
            inputseq.sequence=inputseq.sequence.replace("U","T")
            if len(inputseq.sequence)%3 == 0:
                for i in range(0, len(inputseq.sequence), 3):
                    codondict = {  
                  'ATA':'I', 'ATC':'I', 'ATT':'I', 'ATG':'M',  
                  'ACA':'T', 'ACC':'T', 'ACG':'T', 'ACT':'T',  
                  'AAC':'N', 'AAT':'N', 'AAA':'K', 'AAG':'K',  
                  'AGC':'S', 'AGT':'S', 'AGA':'R', 'AGG':'R',   
                  'CTA':'L', 'CTC':'L', 'CTG':'L', 'CTT':'L',  
                  'CCA':'P', 'CCC':'P', 'CCG':'P', 'CCT':'P',  
                  'CAC':'H', 'CAT':'H', 'CAA':'Q', 'CAG':'Q',  
                  'CGA':'R', 'CGC':'R', 'CGG':'R', 'CGT':'R',  
                  'GTA':'V', 'GTC':'V', 'GTG':'V', 'GTT':'V',  
                  'GCA':'A', 'GCC':'A', 'GCG':'A', 'GCT':'A',  
                  'GAC':'D', 'GAT':'D', 'GAA':'E', 'GAG':'E',  
                  'GGA':'G', 'GGC':'G', 'GGG':'G', 'GGT':'G',  
                  'TCA':'S', 'TCC':'S', 'TCG':'S', 'TCT':'S',  
                  'TTC':'F', 'TTT':'F', 'TTA':'L', 'TTG':'L',  
                  'TAC':'Y', 'TAT':'Y', 'TAA':'_', 'TAG':'_',  
                  'TGC':'C', 'TGT':'C', 'TGA':'_', 'TGG':'W',  
                      }
                    protein= ""
                    val = inputseq.sequence[i:i + 3]   
                    protein+= codondict[val]
                    print(protein)
        elif "T" in inputseq.sequence:
            if len(inputseq.sequence)%3 == 0:
                for i in range(0, len(inputseq.sequence), 3):
                    val = inputseq.sequence[i:i + 3]   
                    protein+= codondict[val]
                    print(protein)

# %%
def test(seq1,seq2):
    """It will check the comptibility of two input sequences"""
    if seq1.seqtype == "DNA" and seq2.seqtype == "DNA": #DNA VS DNA
        print("compatible")
    if seq1.seqtype == "DNA" and seq2.seqtype == "RNA": #DNA vs RNA
        seq1.sequence=seq1.sequence.replace("T","U")
        if seq1.sequence == seq2.sequence: 
            print("compatible")
    if seq1.sequence == "DNA" and seq2.seqtype == "Amino Acid": #DNA vs Amino Acid
        seq1aminoacid = "" 
        for i in range(0, len(seq1.sequence), 3): #Convert DNA to proteins
            seq1aminoacid = seq1aminoacid + codondict[seq1.sequence[i:i+3]] 
            if seq1aminoacid == seq2.sequence:
                print("compatible")
    elif seq1.seqtype == "RNA" and seq2.seqtype == "RNA": #RNA vs RNA
        print("compatible")
    if seq1.seqtype == "RNA" and seq2.seqtype == "DNA": #RNA vs DNA
        seq1.sequence=seq1.sequence.replace("U","T") #converts RNA to DNA
        if seq1.sequence == seq2.sequence: 
            print("compatible")
    if seq1.sequence == "RNA" and seq2.seqtype == "Amino Acid": #RNA vs Amino Acid
        seq1.sequence=seq1.sequence.replace("U","T") #Convert RNA to DNA
        seq1aminoacid = "" 
        for i in range(0, len(seq1.sequence), 3): #Convert DNA to proteins
            seq1aminoacid = seq1aminoacid + codondict[seq1.sequence[i:i+3]] 
            if seq1aminoacid == seq2.sequence:
                print("compatible") 
    elif seq1.seqtype == "Amino Acid" and seq2.seqtype == "Amino Acid": #Amino Acid VS Amino Acid
        print("compatible")
    if seq1.seqtype == "Amino Acid" and seq2.seqtype == "DNA": #Amino acid vs DNA
        seq2aminoacid = "" 
        for i in range(0, len(seq2.sequence), 3): #Convert DNA to proteins
            seq2aminoacid = seq2aminoacid + codondict[seq2.sequence[i:i+3]] 
            if seq2aminoacid == seq1.sequence:
                print("compatible")
    if seq1.sequence == "Amino Acid" and seq2.seqtype == "RNA": #Amino acid vs RNA
        seq2.sequence=seq2.sequence.replace("U","T") #Convert RNA to DNA
        seq2aminoacid = "" 
        for i in range(0, len(seq2.sequence), 3): #Convert DNA to proteins
            seq2aminoacid = seq2aminoacid + codondict[seq2.sequence[i:i+3]] 
            if seq1aminoacid == seq2.sequence:
                print("compatible")

# %%
seq1 = rna("AUGGAGGCAUAA","RNA","a")
seq2 = dna("ATGGAGGCATAA","DNA","a")

test(seq1,seq2)
# Out:
# compatible
